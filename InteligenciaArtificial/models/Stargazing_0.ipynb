# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import os
import random
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# data download and observation
# dataset = '/content/drive/MyDrive/dataset'
# os.chdir(dataset)
# dataset
# os.listdir('/content/drive/MyDrive/dataset')
# data_dir_list = os.listdir('/content/drive/MyDrive/dataset')
# print(data_dir_list)
# OG_dataset_dir = 'dataset'

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
OG_dataset = '/content/dataset/'
os.mkdir(OG_dataset)

stars_folder = '/content/dataset/stars/'
os.mkdir(stars_folder)

planets_folder = '/content/dataset/planets/'
os.mkdir(planets_folder)

nebulas_folder = '/content/dataset/nebulas/'
os.mkdir(nebulas_folder)

blackholes_folder = '/content/dataset/blackholes/'
os.mkdir(blackholes_folder)

meteors_asteroids_folder = '/content/dataset/meteors-asteroids/'
os.mkdir(meteors_asteroids_folder)

galaxies_folder = '/content/dataset/galaxies/'
os.mkdir(galaxies_folder)

test_folder = '/content/dataset/test/'
os.mkdir(test_folder)

# %%
data_dir_list = os.listdir('/content/dataset')
print(data_dir_list[6])
# Out:
# test

# %%
data_dir = ('/content/dataset')

# %%
path, dirs, files = next(os.walk("/content/dataset"))
file_count = len(files)

# %%
# Make new base directory
original_dataset_dir = '/content/dataset'
base_dir = '/content/celestial-bodies-data/'
os.mkdir(base_dir)

# %%
image_exts = ['.jpeg', '.jpg', '.bmp', '.png']

# %%
# for image_class in os.listdir(data_dir):
#     for image in os.listdir(os.path.join(data_dir, image_class)):
#         image_path = os.path.join(data_dir, image_class, image)
#         try :
#             img = cv2.imread(image_path)
#             tip = imghdr.what(image_path)
#             if tip not in image_exts :
#                 print('Image not in ext list {}' .format(image_path))
#                 os.remove(image_path)
#         except Exception as e :
#             print('Issue with image {}' .format(image_path))
# Out:
# Issue with image /content/dataset/blackholes/image6.jpeg
# Issue with image /content/dataset/blackholes/images7.jpg
# Issue with image /content/dataset/blackholes/HT_Black_Holes_NASA_MEM_160525_16x9_992.jpg
# Issue with image /content/dataset/blackholes/images10.jpg
# Issue with image /content/dataset/blackholes/Black-hole-news-NASA-clocked-black-holes-early-universe-Chandra-Xray-NASA-news-1163973.jpg
# Issue with image /content/dataset/blackholes/16611668110229.jpg
# Issue with image /content/dataset/blackholes/image21.jpeg
# Issue with image /content/dataset/blackholes/heic1702d.jpg
# Issue with image /content/dataset/blackholes/image10.jpeg
# Issue with image /content/dataset/blackholes/opo0218d2.jpg
# Issue with image /content/dataset/blackholes/hole-were-converted-into-sound-by-the-us-space-agency_625x300_26_November_22.jpg
# Issue with image /content/dataset/blackholes/opo2302a2.jpg
# Issue with image /content/dataset/blackholes/images5.jpg
# Issue with image /content/dataset/blackholes/heic1702g2.jpg
# Issue with image /content/dataset/blackholes/images13.jpg
# Issue with image /content/dataset/blackholes/image28.jpeg
# Issue with image /content/dataset/blackholes/image29.png
# Issue with image /content/dataset/blackholes/sgra_blackhole_eht.png
# Issue with image /content/dataset/blackholes/259888-n-bh-1.jpg
# Issue with image /content/dataset/blackholes/heic1413b2.jpg
# Issue with image /content/dataset/blackholes/black_hole_xray_radio_label_525.jpg
# Issue with image /content/dataset/blackholes/d2eee5df-cf17-4192-ad87-46b9ed8e8ff3_1920x1080.jpg
# Issue with image /content/dataset/blackholes/potw1411a2.jpg
# Issue with image /content/dataset/blackholes/black-hole-1.jpg
# Issue with image /content/dataset/blackholes/heic1419a.jpg
# Issue with image /content/dataset/blackholes/image24.jpeg
# Issue with image /content/dataset/blackholes/hero-image.fill.size_1200x1200.v1683037162.png
# Issue with image /content/dataset/blackholes/opo0218d.jpg
# Issue with image /content/dataset/blackholes/images16.jpg
# Issue with image /content/dataset/blackholes/image.jpeg
# Issue with image /content/dataset/blackholes/heic1622a.jpg
# Issue with image /content/dataset/blackholes/NASA-black-hole-collision-600.jpg
# Issue with image /content/dataset/blackholes/NASA-Black-hole.jpg
# Issue with image /content/dataset/blackholes/origin-2.gif
# Issue with image /content/dataset/blackholes/image13.jpeg
# Issue with image /content/dataset/blackholes/images8.jpg
# Issue with image /content/dataset/blackholes/image_8284e-3XMM-J215022.4-055108.jpg
# Issue with image /content/dataset/blackholes/images19.jpg
# Issue with image /content/dataset/blackholes/heic1507e.jpg
# Issue with image /content/dataset/blackholes/opo1531b2.jpg
# Issue with image /content/dataset/blackholes/opo1531a.jpg
# Issue with image /content/dataset/blackholes/maxresdefault.jpg
# Issue with image /content/dataset/blackholes/NASAs-Chandra-Observatory-finds-once-hidden-supermassive-black-holes.jpg
# Issue with image /content/dataset/blackholes/HT-nasa-black-hole-illustration-1-jt-170104_16x9_1600.jpg
# Issue with image /content/dataset/blackholes/black-hole-805769.jpg
# Issue with image /content/dataset/blackholes/images18.jpg
# Issue with image /content/dataset/blackholes/heic1706b.jpg
# Issue with image /content/dataset/blackholes/opo1719a2.jpg
# Issue with image /content/dataset/blackholes/images23.jpg
# Issue with image /content/dataset/blackholes/20190410-78m-4000x2330-1.jpg
# Issue with image /content/dataset/blackholes/heic1610a2.jpg
# Issue with image /content/dataset/blackholes/heic1702c2.jpg
# Issue with image /content/dataset/blackholes/whatsapp_image_2023-09-08_at_1.46.35_pm.jpeg
# Issue with image /content/dataset/blackholes/zt2idrnyftshhn1q_1651580679.jpeg
# Issue with image /content/dataset/blackholes/images.jpg
# Issue with image /content/dataset/blackholes/images21.jpg
# Issue with image /content/dataset/blackholes/images6.jpg
# Issue with image /content/dataset/blackholes/opo9423c.jpg
# Issue with image /content/dataset/blackholes/xnys4bjw-1362021626.jpg
# Issue with image /content/dataset/blackholes/images20.jpg
# Issue with image /content/dataset/blackholes/opo2010a.jpg
# Issue with image /content/dataset/blackholes/black-hole.jpg
# Issue with image /content/dataset/blackholes/image16.jpeg
# Issue with image /content/dataset/blackholes/image9.jpeg
# Issue with image /content/dataset/blackholes/image4.jpeg
# Issue with image /content/dataset/blackholes/opo1719b2.jpg
# Issue with image /content/dataset/blackholes/m87-black-hole-enhanced-ai-scaled.jpeg
# Issue with image /content/dataset/blackholes/image18.jpeg
# Issue with image /content/dataset/blackholes/compress_black_hole_sound.jpg
# Issue with image /content/dataset/blackholes/potw1403a2.jpg
# Issue with image /content/dataset/blackholes/image2.jpeg
# Issue with image /content/dataset/blackholes/opo9423c2.jpg
# Issue with image /content/dataset/blackholes/heic1507h.jpg
# Issue with image /content/dataset/blackholes/image25.jpeg
# Issue with image /content/dataset/blackholes/heic1507d.jpg
# Issue with image /content/dataset/blackholes/heic1610a.jpg
# Issue with image /content/dataset/blackholes/image12.jpeg
# Issue with image /content/dataset/blackholes/heic1413a.jpg
# Issue with image /content/dataset/blackholes/photo.jpg
# Issue with image /content/dataset/blackholes/images3.jpg
# Issue with image /content/dataset/blackholes/heic1702f2.jpg
# Issue with image /content/dataset/blackholes/image15.jpeg
# Issue with image /content/dataset/blackholes/blackhole_stellarmass_1653726968898_1653726977589.jpg
# Issue with image /content/dataset/blackholes/Black-holes-could-pose-a-problem-in-the-future-1374292.jpg
# Issue with image /content/dataset/blackholes/e-can-devour-a-bypassing-star-Credits-NASA-ESA-Leah-Hustak-of-STScI-1024x557.jpg
# Issue with image /content/dataset/blackholes/images94.jpg
# Issue with image /content/dataset/blackholes/image8.jpeg
# Issue with image /content/dataset/blackholes/opo15032.jpg
# Issue with image /content/dataset/blackholes/images17.jpg
# Issue with image /content/dataset/blackholes/image5.jpeg
# Issue with image /content/dataset/blackholes/heic1507i.jpg
# Issue with image /content/dataset/blackholes/NASA-Black-Hole-Massive-Star-600.jpg
# Issue with image /content/dataset/blackholes/nasa-s-swift-learns-a-new-trick-spots-a-snacking-black-hole-s.jpg
# Issue with image /content/dataset/blackholes/image23.jpeg
# Issue with image /content/dataset/blackholes/heic1507f2.jpg
# Issue with image /content/dataset/blackholes/STScI-01FMN37V4VGHDJBNEJYZ5RAY70.jpg
# Issue with image /content/dataset/blackholes/heic1507d2.jpg
# Issue with image /content/dataset/blackholes/images24.jpg
# Issue with image /content/dataset/blackholes/69879563-701E-4DB2-AC045396D43B418E_source.jpeg
# Issue with image /content/dataset/blackholes/images26.jpg
# Issue with image /content/dataset/blackholes/opo2114a2.jpg
# Issue with image /content/dataset/blackholes/images12.jpg
# Issue with image /content/dataset/blackholes/heic1507a.jpg
# Issue with image /content/dataset/blackholes/image19.jpeg
# Issue with image /content/dataset/blackholes/heic1413b.jpg
# Issue with image /content/dataset/blackholes/images11.jpg
# Issue with image /content/dataset/blackholes/heic1419a2.jpg
# Issue with image /content/dataset/blackholes/hero-image.fill.size_994x559.v1678673349.jpg
# Issue with image /content/dataset/blackholes/heic1507f.jpg
# Issue with image /content/dataset/blackholes/NASA-discovers-Two-Giant-Black-Holes-moving-towards-a-merger.jpg
# Issue with image /content/dataset/blackholes/maxresdefault2.jpg
# Issue with image /content/dataset/blackholes/image26.jpeg
# Issue with image /content/dataset/blackholes/black-hole-in-space-elements-of-this-image-furnished-by-nasa-JX1JAP.jpg
# Issue with image /content/dataset/blackholes/image20.jpeg
# Issue with image /content/dataset/blackholes/supermassive-black-hole-in-the-early-Universe.jpeg
# Issue with image /content/dataset/blackholes/doublywarpedblackhole_desktop_print1.jpg
# Issue with image /content/dataset/blackholes/Detection.jpg
# Issue with image /content/dataset/blackholes/heic1622b.jpg
# Issue with image /content/dataset/blackholes/heic1507e2.jpg
# Issue with image /content/dataset/blackholes/NASABlackHoleWeek2023.jpg
# Issue with image /content/dataset/blackholes/opo1719a.jpg
# Issue with image /content/dataset/blackholes/nasa-james-webb-ceers-1019-supermassive-black-hole-28175.jpg
# Issue with image /content/dataset/blackholes/image27.jpeg
# Issue with image /content/dataset/blackholes/image14.jpeg
# Issue with image /content/dataset/blackholes/images27.jpg
# Issue with image /content/dataset/blackholes/heic1507c.jpg
# Issue with image /content/dataset/blackholes/baby-black-hole-nasa-chandra-061511-D3D948.jpg
# Issue with image /content/dataset/blackholes/1021292_1_0104-black-holes_standard.jpg
# Issue with image /content/dataset/blackholes/NASA-animation-sizes-up-the-biggest-black-holes.jpg
# Issue with image /content/dataset/blackholes/blackhole_1600.jpg
# Issue with image /content/dataset/blackholes/092719_mt_blackhole_inline_680-1.gif
# Issue with image /content/dataset/blackholes/heic1507c2.jpg
# Issue with image /content/dataset/blackholes/images25.jpg
# Issue with image /content/dataset/blackholes/1483686940-black-hole.jpg
# Issue with image /content/dataset/blackholes/v404cyg_lg-scaled.jpeg
# Issue with image /content/dataset/blackholes/images4.jpg
# Issue with image /content/dataset/blackholes/images15.jpg
# Issue with image /content/dataset/blackholes/thequint2F2016-042F793fe18d-0be1-40b9-9ced-1b21176ef7432FNasa-Hero.jpg
# Issue with image /content/dataset/blackholes/heic2005c2.jpg
# Issue with image /content/dataset/blackholes/Black-Hole-Destroys-a-Star-Illustration-scaled.jpg
# Issue with image /content/dataset/blackholes/heic1902a.jpg
# Issue with image /content/dataset/blackholes/heic1413a2.jpg
# Issue with image /content/dataset/blackholes/heic1702c.jpg
# Issue with image /content/dataset/blackholes/AdobeStock_111475883.jpg
# Issue with image /content/dataset/blackholes/d-by-nasa-a-monster-black-hole-glowing-in-deep-space-ai-generated-free-photo.jpg
# Issue with image /content/dataset/blackholes/heic1507b2.jpg
# Issue with image /content/dataset/blackholes/images9.jpg
# Issue with image /content/dataset/blackholes/heic1507g.jpg
# Issue with image /content/dataset/blackholes/dSf5QLZL8yBvaf9bWsqLDY.jpg
# Issue with image /content/dataset/blackholes/images22.jpg
# Issue with image /content/dataset/blackholes/image22.jpeg
# Issue with image /content/dataset/blackholes/heic2005d2.jpg
# Issue with image /content/dataset/blackholes/heic1507b.jpg
# Issue with image /content/dataset/blackholes/images14.jpg
# Issue with image /content/dataset/blackholes/image3.jpeg
# Issue with image /content/dataset/blackholes/image7.jpeg
# Issue with image /content/dataset/blackholes/heic2005c.jpg
# Issue with image /content/dataset/blackholes/cena-e1683268577289.jpg
# Issue with image /content/dataset/blackholes/image11.jpeg
# Issue with image /content/dataset/blackholes/image17.jpeg
# Issue with image /content/dataset/blackholes/hubblegazesi.jpg
# Issue with image /content/dataset/blackholes/Supermassive-Black-Holes-Merging-Illustration.jpg
# Issue with image /content/dataset/planets/image6.jpeg
# Issue with image /content/dataset/planets/6007df95a963a-toi-1338-b-planet-nasa-wolf-cukier-coverimage.jpg
# Issue with image /content/dataset/planets/DJj0n4nr3Iu6_130x130_hwsA1GW5.png
# Issue with image /content/dataset/planets/PIA11518thumb.jpg
# Issue with image /content/dataset/planets/images7.jpg
# Issue with image /content/dataset/planets/planet9.jpg
# Issue with image /content/dataset/planets/images10.jpg
# Issue with image /content/dataset/planets/PIA12631thumb.jpg
# Issue with image /content/dataset/planets/STScI-01EVSQZGVJZXXHM1E9KXPBJRFE.png
# Issue with image /content/dataset/planets/image21.jpeg
# Issue with image /content/dataset/planets/images29.jpg
# Issue with image /content/dataset/planets/0x0.jpg
# Issue with image /content/dataset/planets/PIA19346thumb.jpg
# Issue with image /content/dataset/planets/PIA17998thumb.jpg
# Issue with image /content/dataset/planets/images5.jpg
# Issue with image /content/dataset/planets/TsNMvdptH5oj_130x130_EqrVOeCm.png
# Issue with image /content/dataset/planets/negro-los-elementos-de-esta-imagen-fueron-proporcionadas-por-la-nasa-2a9tnrf.jpg
# Issue with image /content/dataset/planets/Viral_Instagram_Planet_Rainbow_Nasa_1658316556293_1658316573815_1658316573815.PNG.jpg
# Issue with image /content/dataset/planets/dreamstime_xxl_121672573-scaled.jpg
# Issue with image /content/dataset/planets/FYUZyaSfneVU_130x130_Ts4C1s9P.png
# Issue with image /content/dataset/planets/PIA09784thumb.jpg
# Issue with image /content/dataset/planets/images13.jpg
# Issue with image /content/dataset/planets/nasa-planets.jpeg
# Issue with image /content/dataset/planets/PIA20698thumb.jpg
# Issue with image /content/dataset/planets/Lqn4JV3A9KsP_130x130_y5H8FgV_.png
# Issue with image /content/dataset/planets/Earth-and-Exoplanet-Kepler-138-d-Cross-Sections-scaled.jpg
# Issue with image /content/dataset/planets/PIA03048thumb.jpg
# Issue with image /content/dataset/planets/1000_F_332412385_f4VXNkb6l55iL4qyirsRCkPIFdPylWrH.jpg
# Issue with image /content/dataset/planets/tCN_sBiITgAY_130x130_OA9fEFRf.png
# Issue with image /content/dataset/planets/PIA18901thumb.jpg
# Issue with image /content/dataset/planets/PIA01282thumb.jpg
# Issue with image /content/dataset/planets/4EZhmfqjiCpZ_130x130_bgKrqLcD.png
# Issue with image /content/dataset/planets/image24.jpeg
# Issue with image /content/dataset/planets/PIA12365thumb.jpg
# Issue with image /content/dataset/planets/1350560502112526342-png__700.jpg
# Issue with image /content/dataset/planets/PIA22233thumb.jpg
# Issue with image /content/dataset/planets/ARC-1977-AC77-0359thumb.jpg
# Issue with image /content/dataset/planets/images16.jpg
# Issue with image /content/dataset/planets/Exoplanet_Scale-3840_1662106737632_1662106751374_1662106751374.jpg
# Issue with image /content/dataset/planets/image.jpeg
# Issue with image /content/dataset/planets/qkXDRxyhCuC6_130x130_Ah_InWCJ.png
# Issue with image /content/dataset/planets/AP17348693298433.jpg
# Issue with image /content/dataset/planets/oRofEQifiY4X_130x130_22L2LhJ6.png
# Issue with image /content/dataset/planets/EocHfGTgHtNu_130x130_UbRgOO6h.png
# Issue with image /content/dataset/planets/gj357_dthm.jpg
# Issue with image /content/dataset/planets/PIA21906thumb.jpg
# Issue with image /content/dataset/planets/02NASA2-videoSixteenByNine3000.jpg
# Issue with image /content/dataset/planets/image13.jpeg
# Issue with image /content/dataset/planets/images8.jpg
# Issue with image /content/dataset/planets/images19.jpg
# Issue with image /content/dataset/planets/CloWIxQLYOch_130x130_gKPtQLff.png
# Issue with image /content/dataset/planets/47csarng_mars-once-had-oceanlike-water-on-its-surface-claims-study_625x300_28_November_22.jpg
# Issue with image /content/dataset/planets/PIA18921thumb.jpg
# Issue with image /content/dataset/planets/PIA14886thumb.jpg
# Issue with image /content/dataset/planets/230517130418-planet-lp-791-18-d.jpg
# Issue with image /content/dataset/planets/7005_1332_lava_1654503170008_1654503175752.jpg
# Issue with image /content/dataset/planets/maxresdefault.jpg
# Issue with image /content/dataset/planets/PIA12567thumb.jpg
# Issue with image /content/dataset/planets/shxYQmxo0Vqx_130x130_atrCQSBJ.png
# Issue with image /content/dataset/planets/GSFC_20171208_Archive_e002090thumb.jpg
# Issue with image /content/dataset/planets/_84295057_planets_nasa.jpg
# Issue with image /content/dataset/planets/IHIUWRqmemxm_130x130_pC5B14iE.png
# Issue with image /content/dataset/planets/4-6006c7351d294__700.jpg
# Issue with image /content/dataset/planets/TYHWVBBoQfEe_130x130_V1nQfcB5.png
# Issue with image /content/dataset/planets/1_exploring_jupiter_vp.jpg
# Issue with image /content/dataset/planets/tDVrixOPsZMb_130x130_5ObD52Fp.png
# Issue with image /content/dataset/planets/images18.jpg
# Issue with image /content/dataset/planets/7zS2sMF6gqQ6_130x130_OAxLofvp.png
# Issue with image /content/dataset/planets/OOSns_PVsqYZ_130x130_D2IijuTK.png
# Issue with image /content/dataset/planets/images23.jpg
# Issue with image /content/dataset/planets/PIA16853thumb.jpg
# Issue with image /content/dataset/planets/480x320_venus.png
# Issue with image /content/dataset/planets/220321182045-exoplanet-diversity-illustration.jpg
# Issue with image /content/dataset/planets/images.jpg
# Issue with image /content/dataset/planets/images21.jpg
# Issue with image /content/dataset/planets/67uBcBoz8W82_130x130_e3i-LATF.png
# Issue with image /content/dataset/planets/images6.jpg
# Issue with image /content/dataset/planets/PIA23002thumb.jpg
# Issue with image /content/dataset/planets/planet(12).jpeg
# Issue with image /content/dataset/planets/PIA11247thumb.jpg
# Issue with image /content/dataset/planets/PIA09377thumb.jpg
# Issue with image /content/dataset/planets/desktop-wallpaper-jupiter-clouds-space-nasa-space-and-astronomy-planets-nasa-jupiter.jpg
# Issue with image /content/dataset/planets/images20.jpg
# Issue with image /content/dataset/planets/pngtree-giant-planet-from-nasa-picture-image_2669057.jpg
# Issue with image /content/dataset/planets/GSFC_20171208_Archive_e001454thumb.jpg
# Issue with image /content/dataset/planets/NASA-1200x675-1.jpeg
# Issue with image /content/dataset/planets/-space-background-elements-this-image-furnished-by-nasa-3d-render_550395-580.jpg
# Issue with image /content/dataset/planets/PIA22093thumb.jpg
# Issue with image /content/dataset/planets/PIA10109thumb.jpg
# Issue with image /content/dataset/planets/image16.jpeg
# Issue with image /content/dataset/planets/PIA19344thumb.jpg
# Issue with image /content/dataset/planets/PIA22098thumb.jpg
# Issue with image /content/dataset/planets/image9.jpeg
# Issue with image /content/dataset/planets/image4.jpeg
# Issue with image /content/dataset/planets/jupiter_480x320_new.jpg
# Issue with image /content/dataset/planets/PIA10969thumb.jpg
# Issue with image /content/dataset/planets/planet_1623506170159_1623506176455.jpg
# Issue with image /content/dataset/planets/image18.jpeg
# Issue with image /content/dataset/planets/R0tOn-v-hIPr_130x130_iBB9dZR5.png
# Issue with image /content/dataset/planets/1-nasa.jpg
# Issue with image /content/dataset/planets/image2.jpeg
# Issue with image /content/dataset/planets/PIA11800thumb.jpg
# Issue with image /content/dataset/planets/PIA22086thumb.jpg
# Issue with image /content/dataset/planets/PIA09917thumb.jpg
# Issue with image /content/dataset/planets/1000_F_504797807_vZBkGXTbDzHSuV5NJm6OOrlFY1ftxoJ2.jpg
# Issue with image /content/dataset/planets/image25.jpeg
# Issue with image /content/dataset/planets/PIA14801thumb.jpg
# Issue with image /content/dataset/planets/PIA01243thumb.jpg
# Issue with image /content/dataset/planets/PIA06604thumb.jpg
# Issue with image /content/dataset/planets/GSFC_20171208_Archive_e001427thumb.jpg
# Issue with image /content/dataset/planets/saturn-visuals-show-the-ring-shining-bright-nasa-astronomers-note-surprising-details.jpg
# Issue with image /content/dataset/planets/tLnUbaGRBuj0_130x130_RUF1ZCHg.png
# Issue with image /content/dataset/planets/1bn1lby-pIAw_130x130_9eV1F670.png
# Issue with image /content/dataset/planets/image12.jpeg
# Issue with image /content/dataset/planets/MSwYP8pmOO2w_130x130_PXUNQWES.png
# Issue with image /content/dataset/planets/PIA22229thumb.jpg
# Issue with image /content/dataset/planets/images3.jpg
# Issue with image /content/dataset/planets/GSFC_20171208_Archive_e000019thumb.jpg
# Issue with image /content/dataset/planets/planet(11).jpeg
# Issue with image /content/dataset/planets/image15.jpeg
# Issue with image /content/dataset/planets/PIA16888thumb.jpg
# Issue with image /content/dataset/planets/PIA01253thumb.jpg
# Issue with image /content/dataset/planets/solar-system-elements-this-image-furnished-by-nasa_103740-333.jpg
# Issue with image /content/dataset/planets/PIA22097thumb.jpg
# Issue with image /content/dataset/planets/91rQF4BL4XL._AC_UF8941000_QL80_.jpg
# Issue with image /content/dataset/planets/PIA23870thumb.jpg
# Issue with image /content/dataset/planets/CliRC79DMXR8_130x130_Sep3p-hg.png
# Issue with image /content/dataset/planets/image8.jpeg
# Issue with image /content/dataset/planets/EZSU-RtWsAEyI7x.jpg
# Issue with image /content/dataset/planets/gj504b_exoplanet_final_0-300x168.jpg
# Issue with image /content/dataset/planets/images17.jpg
# Issue with image /content/dataset/planets/image5.jpeg
# Issue with image /content/dataset/planets/planet(5).jpeg
# Issue with image /content/dataset/planets/planet(7).jpeg
# Issue with image /content/dataset/planets/jVMCdBlBWdoD_130x130_u36WiIjx.png
# Issue with image /content/dataset/planets/S91-32389thumb.jpg
# Issue with image /content/dataset/planets/file-20210215-17-u97469.jpg
# Issue with image /content/dataset/planets/planet(13).jpeg
# Issue with image /content/dataset/planets/Exo-Neptune_art1280.jpeg
# Issue with image /content/dataset/planets/1232167-planets-nasa-stunning-images.jpg
# Issue with image /content/dataset/planets/image23.jpeg
# Issue with image /content/dataset/planets/9ye1EPMr0srt_130x130_vObbIlAw.png
# Issue with image /content/dataset/planets/planet-circles-two-stars-nasa-02-ht-jc-200109_hpMain_16x9_1600.jpg
# Issue with image /content/dataset/planets/PIA09259thumb.jpg
# Issue with image /content/dataset/planets/PIA10376thumb.jpg
# Issue with image /content/dataset/planets/PIA16852thumb.jpg
# Issue with image /content/dataset/planets/a5qQWVl9oBaI_130x130_cI7A1Dqh.png
# Issue with image /content/dataset/planets/images24.jpg
# Issue with image /content/dataset/planets/planet(8).jpeg
# Issue with image /content/dataset/planets/images26.jpg
# Issue with image /content/dataset/planets/images12.jpg
# Issue with image /content/dataset/planets/image19.jpeg
# Issue with image /content/dataset/planets/PIA08042thumb.jpg
# Issue with image /content/dataset/planets/PIA09844thumb.jpg
# Issue with image /content/dataset/planets/images11.jpg
# Issue with image /content/dataset/planets/dreamstime_xl_149734409-scaled.jpg
# Issue with image /content/dataset/planets/PIA01936thumb.jpg
# Issue with image /content/dataset/planets/PIA12015thumb.jpg
# Issue with image /content/dataset/planets/PIA21468thumb.jpg
# Issue with image /content/dataset/planets/nasa-tess-1-ht-gmh-230110_1673402992318_hpMain_16x9_1600.jpg
# Issue with image /content/dataset/planets/PIA18926thumb.jpg
# Issue with image /content/dataset/planets/d7b4206d9182977197b2a5048fec46d5.jpg
# Issue with image /content/dataset/planets/PIA15629thumb.jpg
# Issue with image /content/dataset/planets/GSFC_20171208_Archive_e000211thumb.jpg
# Issue with image /content/dataset/planets/image20.jpeg
# Issue with image /content/dataset/planets/81WnJS5-uoL._AC_UF10001000_QL80_.jpg
# Issue with image /content/dataset/planets/planet(6).jpeg
# Issue with image /content/dataset/planets/nasa-1113865.jpg
# Issue with image /content/dataset/planets/e-background-elements-image-were-furnished-nasa-high-quality-photo-240768613.jpg
# Issue with image /content/dataset/planets/NASA20discovered20a20bigger20earth-like20planet.jpg
# Issue with image /content/dataset/planets/planet(1).jpeg
# Issue with image /content/dataset/planets/Jupiter-4k.png
# Issue with image /content/dataset/planets/34D3E9DC-9879-406C-A323-DF23360107B5.jpeg
# Issue with image /content/dataset/planets/image14.jpeg
# Issue with image /content/dataset/planets/STScI-01H9R8AEK6Y7QR03MGN9V9P6ZJ-e1694539911695.jpg
# Issue with image /content/dataset/planets/planet(9).jpeg
# Issue with image /content/dataset/planets/230110102813-nasa-toi-700-e-planet.jpg
# Issue with image /content/dataset/planets/images27.jpg
# Issue with image /content/dataset/planets/jupiter-webb-telescope-01-ht-iwb-220822_1661177358675_hpMain_16x9_1600.jpg
# Issue with image /content/dataset/planets/22sci-mars1-videoSixteenByNine3000.jpg
# Issue with image /content/dataset/planets/PIA13034thumb.jpg
# Issue with image /content/dataset/planets/e519f28675861a58d94ce91a6b406bdc.jpg
# Issue with image /content/dataset/planets/images2.jpg
# Issue with image /content/dataset/planets/PIA18837thumb.jpg
# Issue with image /content/dataset/planets/PIA07695thumb.jpg
# Issue with image /content/dataset/planets/22170541-ef4053dc-2d94-4796-a65e-a1729681fb78.png
# Issue with image /content/dataset/planets/images25.jpg
# Issue with image /content/dataset/planets/nasa-new-planet-pics-1-1200x900-cropped.jpg
# Issue with image /content/dataset/planets/PIA19827thumb.jpg
# Issue with image /content/dataset/planets/mars_480x320.jpg
# Issue with image /content/dataset/planets/PIA11392thumb.jpg
# Issue with image /content/dataset/planets/images28.jpg
# Issue with image /content/dataset/planets/images4.jpg
# Issue with image /content/dataset/planets/PIA15621thumb.jpg
# Issue with image /content/dataset/planets/PIA09196thumb.jpg
# Issue with image /content/dataset/planets/PIA13691thumb.jpg
# Issue with image /content/dataset/planets/image1stscihp1807af3200x4000-1517863019.png
# Issue with image /content/dataset/planets/images15.jpg
# Issue with image /content/dataset/planets/m6SXpMHWNYKv_130x130_Bw5ydgj6.png
# Issue with image /content/dataset/planets/planet(10).jpeg
# Issue with image /content/dataset/planets/GDVf4nxqBSh-_130x130_-WGu7WT2.png
# Issue with image /content/dataset/planets/c0e95191-ce58-47e9-9612-600b204db6a0.jpg
# Issue with image /content/dataset/planets/PIA16693thumb.jpg
# Issue with image /content/dataset/planets/81145_100_heres-all-of-the-planets-in-our-solar-system-ranked_full.jpg
# Issue with image /content/dataset/planets/PIA14354thumb.jpg
# Issue with image /content/dataset/planets/PIA05988thumb.jpg
# Issue with image /content/dataset/planets/PIA21422thumb.jpg
# Issue with image /content/dataset/planets/planet(3).jpeg
# Issue with image /content/dataset/planets/mercury_480x320_new.jpg
# Issue with image /content/dataset/planets/0301771thumb.jpg
# Issue with image /content/dataset/planets/images9.jpg
# Issue with image /content/dataset/planets/images22.jpg
# Issue with image /content/dataset/planets/PIA17999thumb.jpg
# Issue with image /content/dataset/planets/image22.jpeg
# Issue with image /content/dataset/planets/5063392410_171f23ef25_b.jpg
# Issue with image /content/dataset/planets/images14.jpg
# Issue with image /content/dataset/planets/image3.jpeg
# Issue with image /content/dataset/planets/PIA20692thumb.jpg
# Issue with image /content/dataset/planets/image7.jpeg
# Issue with image /content/dataset/planets/planet(2).jpeg
# Issue with image /content/dataset/planets/PIA17830thumb.jpg
# Issue with image /content/dataset/planets/PIA10106thumb.jpg
# Issue with image /content/dataset/planets/saturn_480x320.jpg
# Issue with image /content/dataset/planets/image11.jpeg
# Issue with image /content/dataset/planets/image17.jpeg
# Issue with image /content/dataset/planets/NASA-planet-discovery-TESS-new-plants-extraterrestrial-alien-life-NASA-news-1158211.jpg
# Issue with image /content/dataset/planets/Credit-Earth.com_.png
# Issue with image /content/dataset/planets/PIA02350thumb.jpg
# Issue with image /content/dataset/planets/PIA21430thumb.jpg
# Issue with image /content/dataset/planets/planet(4).jpeg
# Issue with image /content/dataset/nebulas/PIA11968thumb.jpg
# Issue with image /content/dataset/nebulas/PIA23646thumb.jpg
# Issue with image /content/dataset/nebulas/PIA04225thumb.jpg
# Issue with image /content/dataset/nebulas/6lhcJjWmI3PS_130x130_jRgXeyOK.png
# Issue with image /content/dataset/nebulas/uKij9-p1j5Dk_130x130_8qnF73cE.png
# Issue with image /content/dataset/nebulas/fEaathQ-RnO2_130x130_dF-urcSz.png
# Issue with image /content/dataset/nebulas/y-hcYRzHS4az_130x130_cxlqi78I.png
# Issue with image /content/dataset/nebulas/PIA04226thumb.jpg
# Issue with image /content/dataset/nebulas/taQIolD1GbE3_130x130_xQIMO36-.png
# Issue with image /content/dataset/nebulas/kDWktA50U6Fm_130x130_P9vRdkJw.png
# Issue with image /content/dataset/nebulas/xufeafnVLlWY_130x130_Yt9enQh3.png
# Issue with image /content/dataset/nebulas/39_Gsqi3Uojy_130x130_FUP24ILn.png
# Issue with image /content/dataset/nebulas/PIA18249thumb.jpg
# Issue with image /content/dataset/nebulas/tMOyDejjFNoA_130x130_MiL8cxkI.png
# Issue with image /content/dataset/nebulas/bvShNQUhLg_B_130x130_AAKHxYqr.png
# Issue with image /content/dataset/nebulas/PIA03515thumb.jpg
# Issue with image /content/dataset/nebulas/PIA13111thumb.jpg
# Issue with image /content/dataset/nebulas/PIA03294thumb.jpg
# Issue with image /content/dataset/nebulas/PIA15635thumb.jpg
# Issue with image /content/dataset/nebulas/PIA13014thumb.jpg
# Issue with image /content/dataset/nebulas/iltvLQ_NYtqf_130x130_Gjj23Y4Z.png
# Issue with image /content/dataset/nebulas/H97ByJtxvCKi_130x130_9FHea9in.png
# Issue with image /content/dataset/nebulas/eUtu_wiBsyB3_130x130_Tvl0TZwZ.png
# Issue with image /content/dataset/nebulas/PIA15415thumb.jpg
# Issue with image /content/dataset/nebulas/PIA17563thumb.jpg
# Issue with image /content/dataset/nebulas/PIA04216thumb.jpg
# Issue with image /content/dataset/nebulas/6yJgT3lJd1u3_130x130_tM6xw2B4.png
# Issue with image /content/dataset/nebulas/W8KoKBbiqVr2_130x130_Bp1SZAQN.png
# Issue with image /content/dataset/nebulas/6bc_VcD_rZ5K_130x130_XE8uVNa2.png
# Issue with image /content/dataset/nebulas/0NjGJIKI9GQI_130x130_bizLI7y7.png
# Issue with image /content/dataset/nebulas/PIA13028thumb.jpg
# Issue with image /content/dataset/nebulas/PIA07343thumb.jpg
# Issue with image /content/dataset/nebulas/X7GYonZmkRLH_130x130_ADpx3Mob.png
# Issue with image /content/dataset/nebulas/GJmcZ4bo556q_130x130_X5qr6S0u.png
# Issue with image /content/dataset/nebulas/H05vSdLOksEx_130x130_tO__n-AJ.png
# Issue with image /content/dataset/nebulas/5wH_leJnHook_130x130_itgPNZaJ.png
# Issue with image /content/dataset/nebulas/viKWmM4e_7jY_130x130_ebnCeGls.png
# Issue with image /content/dataset/nebulas/PeRnN2Wa-Ts4_130x130_GQnHSnL6.png
# Issue with image /content/dataset/nebulas/clLkSFc02FTz_130x130__SOGEWSS.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002020thumb.jpg
# Issue with image /content/dataset/nebulas/0203048thumb.jpg
# Issue with image /content/dataset/nebulas/carina_nebulathumb.jpg
# Issue with image /content/dataset/nebulas/ki7BMqvn2YSK_130x130_-WnUvKAG.png
# Issue with image /content/dataset/nebulas/838iWE-74rVa_130x130_CWMjIBjW.png
# Issue with image /content/dataset/nebulas/PIA04249thumb.jpg
# Issue with image /content/dataset/nebulas/ttI7bnI1f1Lq_130x130_2AvRihOE.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000134thumb.jpg
# Issue with image /content/dataset/nebulas/PIA14444thumb.jpg
# Issue with image /content/dataset/nebulas/0302064thumb.jpg
# Issue with image /content/dataset/nebulas/PIA07902thumb.jpg
# Issue with image /content/dataset/nebulas/PIA13118thumb.jpg
# Issue with image /content/dataset/nebulas/9i9kd3zRUMmh_130x130_AuzPIzi1.png
# Issue with image /content/dataset/nebulas/uJjvChooX8_n_130x130_byrxWDdV.png
# Issue with image /content/dataset/nebulas/uhb3SeYwiURq_130x130_7b7_vogr.png
# Issue with image /content/dataset/nebulas/PIA13451thumb.jpg
# Issue with image /content/dataset/nebulas/PIA24577thumb.jpg
# Issue with image /content/dataset/nebulas/PIA25434thumb.jpg
# Issue with image /content/dataset/nebulas/PIA14092thumb.jpg
# Issue with image /content/dataset/nebulas/southern_ring_nebulathumb.jpg
# Issue with image /content/dataset/nebulas/PIA03606thumb.jpg
# Issue with image /content/dataset/nebulas/Q2dX4wY-e-wS_130x130_MXKxWIVf.png
# Issue with image /content/dataset/nebulas/vkiS2YRmuSRs_130x130_-iOaUGvJ.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e001465thumb.jpg
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000148thumb.jpg
# Issue with image /content/dataset/nebulas/PIA04227thumb.jpg
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000054thumb.jpg
# Issue with image /content/dataset/nebulas/fGDw0K8iZVJ4_130x130_MiEtNPXe.png
# Issue with image /content/dataset/nebulas/0302063thumb.jpg
# Issue with image /content/dataset/nebulas/PIA07225thumb.jpg
# Issue with image /content/dataset/nebulas/1ZSPK1jit8oR_130x130_z5jv0FL3.png
# Issue with image /content/dataset/nebulas/E90ARGjVq63E_130x130_Lksp6BpQ.png
# Issue with image /content/dataset/nebulas/PIA14728thumb.jpg
# Issue with image /content/dataset/nebulas/FgWaMWv-Fbu0_130x130_3kUhbLu6.png
# Issue with image /content/dataset/nebulas/p6vm5Jdl9G8J_130x130_Y29fM1NW.png
# Issue with image /content/dataset/nebulas/PIA09178thumb.jpg
# Issue with image /content/dataset/nebulas/PIA21474thumb.jpg
# Issue with image /content/dataset/nebulas/hubble-sees-the-wings-of-a-butterfly-the-twin-jet-nebula_20283986193_othumb.jpg
# Issue with image /content/dataset/nebulas/Ojz1sQmZ4T5B_130x130_RL34VNUK.png
# Issue with image /content/dataset/nebulas/PIA20357thumb.jpg
# Issue with image /content/dataset/nebulas/GMAjMH8pJDKN_130x130_FpuL5VeD.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002155thumb.jpg
# Issue with image /content/dataset/nebulas/IzvRipsWlEI1_130x130_Ur4AtWMN.png
# Issue with image /content/dataset/nebulas/fvuflZCkvDqG_130x130_0Bra9s-e.png
# Issue with image /content/dataset/nebulas/FeG4br3kb0F4_130x130_D3u-y4Ix.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000273thumb.jpg
# Issue with image /content/dataset/nebulas/uEeeQkYBdC_D_130x130_HodCFeT2.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e001915thumb.jpg
# Issue with image /content/dataset/nebulas/FOlTRBvU_8MV_130x130_SLcU9xdS.png
# Issue with image /content/dataset/nebulas/PIA23409thumb.jpg
# Issue with image /content/dataset/nebulas/OkyuaaeuVeUD_130x130_j3T5amiN.png
# Issue with image /content/dataset/nebulas/K5MDTtC8ND3w_130x130_QbXarQ74.png
# Issue with image /content/dataset/nebulas/IArk6ttL8Uib_130x130_73xgYGE8.png
# Issue with image /content/dataset/nebulas/FWPo8IU-nNw__130x130_5yBFz2yW.png
# Issue with image /content/dataset/nebulas/FwvpqPyPz1Gu_130x130_wSxT-I8v.png
# Issue with image /content/dataset/nebulas/1mUOXaNFowA__130x130_c59bD1ex.png
# Issue with image /content/dataset/nebulas/d9Xo6AUVUfsl_130x130_dtzUZBge.png
# Issue with image /content/dataset/nebulas/p-gotgON1PqH_130x130_VspyFFMr.png
# Issue with image /content/dataset/nebulas/HV-rYnqkGah8_130x130_NFaA2dRH.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e001743thumb.jpg
# Issue with image /content/dataset/nebulas/tCQtrq_m_ZeM_130x130_5p8LQV3h.png
# Issue with image /content/dataset/nebulas/fcxRBEJOlC1R_130x130_h3fie_t_.png
# Issue with image /content/dataset/nebulas/PIA25433thumb.jpg
# Issue with image /content/dataset/nebulas/PIA10955thumb.jpg
# Issue with image /content/dataset/nebulas/7fn3cROzJY19_130x130_dDLsVhm7.png
# Issue with image /content/dataset/nebulas/PIA09268thumb.jpg
# Issue with image /content/dataset/nebulas/xghNZz1uXR22_130x130_Ew4bN5hZ.png
# Issue with image /content/dataset/nebulas/WyGrgF6GMQvl_130x130_BDkjA3PF.png
# Issue with image /content/dataset/nebulas/PIA13453thumb.jpg
# Issue with image /content/dataset/nebulas/0300724thumb.jpg
# Issue with image /content/dataset/nebulas/PIA13110thumb.jpg
# Issue with image /content/dataset/nebulas/4G4iGqEX29Kl_130x130_QngMy18K.png
# Issue with image /content/dataset/nebulas/global-header_bg..png
# Issue with image /content/dataset/nebulas/z95NqGvWjsAb_130x130_G7nXPiUs.png
# Issue with image /content/dataset/nebulas/Udre8mSFQpVv_130x130_IhFIpn4T.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002086thumb.jpg
# Issue with image /content/dataset/nebulas/LSbM6kURHjSs_130x130_wzLmM8TL.png
# Issue with image /content/dataset/nebulas/3IBg_Zwfq_Ip_130x130_QPUmZJSQ.png
# Issue with image /content/dataset/nebulas/PIA13845thumb.jpg
# Issue with image /content/dataset/nebulas/7fj5L8ymiimu_130x130_nEadSDJW.png
# Issue with image /content/dataset/nebulas/agZrYmhzFyjl_130x130_NV1FDFWf.png
# Issue with image /content/dataset/nebulas/a2XqK4jIJRG0_130x130_ITnRTCGc.png
# Issue with image /content/dataset/nebulas/r4YGIee-TgHR_130x130_SPhwjnIc.png
# Issue with image /content/dataset/nebulas/PIA14104thumb.jpg
# Issue with image /content/dataset/nebulas/AJMJbpw8bm6Q_130x130_WYwYeZ6f.png
# Issue with image /content/dataset/nebulas/PIA14731thumb.jpg
# Issue with image /content/dataset/nebulas/G0aIku0jwmeH_130x130_C8zhA0ck.png
# Issue with image /content/dataset/nebulas/hubble-finds-a-little-gem_20185002499_othumb.jpg
# Issue with image /content/dataset/nebulas/53sNn1qyMq8k_130x130_u6rCPfFk.png
# Issue with image /content/dataset/nebulas/PIA13127thumb.jpg
# Issue with image /content/dataset/nebulas/PIA14038thumb.jpg
# Issue with image /content/dataset/nebulas/yzMf9zWFyJK-_130x130_-S7FTZuz.png
# Issue with image /content/dataset/nebulas/mW0QbOp93vAQ_130x130_K_G17n4m.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000637thumb.jpg
# Issue with image /content/dataset/nebulas/aLiCykCwzV12_130x130_q6u5x_Nf.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000053thumb.jpg
# Issue with image /content/dataset/nebulas/TsYfzCviFyg6_130x130_y0094Luz.png
# Issue with image /content/dataset/nebulas/W67OFq4dTno6_130x130_Du6-cVEU.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002076thumb.jpg
# Issue with image /content/dataset/nebulas/jyUTnoxpAAVO_130x130_O0f9JujQ.png
# Issue with image /content/dataset/nebulas/NG-uEFEqNvFJ_130x130_UOSWtzFK.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e001518thumb.jpg
# Issue with image /content/dataset/nebulas/l6f3Wr0XwOgr_130x130_WlB3rnk9.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000699thumb.jpg
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e001955thumb.jpg
# Issue with image /content/dataset/nebulas/PIA07773thumb.jpg
# Issue with image /content/dataset/nebulas/PIA15658thumb.jpg
# Issue with image /content/dataset/nebulas/f84NnfbTvbRI_130x130_cOdAOF-s.png
# Issue with image /content/dataset/nebulas/gPRD0wQ6vrHE_130x130_Vkcl3IN_.png
# Issue with image /content/dataset/nebulas/NPZhHUxnHe2C_130x130_T1s_wF1y.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002075thumb.jpg
# Issue with image /content/dataset/nebulas/q_m8uVK2kgfh_130x130_sio0iwLt.png
# Issue with image /content/dataset/nebulas/0DsRuhMXuu0z_130x130_HvKCCF_W.png
# Issue with image /content/dataset/nebulas/PIA23867thumb.jpg
# Issue with image /content/dataset/nebulas/ICa-Xg6yhSl__130x130_9LewjJ68.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e000195thumb.jpg
# Issue with image /content/dataset/nebulas/ramV38l_gdFa_130x130_mYvGh8eo.png
# Issue with image /content/dataset/nebulas/BYZILDAcUWWq_130x130_x1ZSKUZP.png
# Issue with image /content/dataset/nebulas/JrT9TT9c6okM_130x130_vGHAiZPn.png
# Issue with image /content/dataset/nebulas/hubble-view-of-a-nitrogen-rich-nebula_19178136615_othumb.jpg
# Issue with image /content/dataset/nebulas/pTbTTmkPjLI__130x130_qaqIGnsb.png
# Issue with image /content/dataset/nebulas/7890338thumb.jpg
# Issue with image /content/dataset/nebulas/craEh15-We-p_130x130_ihHebOU2.png
# Issue with image /content/dataset/nebulas/ZTaT75ct6tNq_130x130_zjEm_9QK.png
# Issue with image /content/dataset/nebulas/gblQmnQoeQ_4_130x130_TurAwmBN.png
# Issue with image /content/dataset/nebulas/lRu1pkYxtdEY_130x130_J3oFNVQy.png
# Issue with image /content/dataset/nebulas/QbmkUdK2OMs__130x130_YIrF5Ut_.png
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002152thumb.jpg
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e001464thumb.jpg
# Issue with image /content/dataset/nebulas/PIA14417thumb.jpg
# Issue with image /content/dataset/nebulas/GSFC_20171208_Archive_e002159thumb.jpg
# Issue with image /content/dataset/nebulas/8dZJV6Cg-IXQ_130x130_XsRduYDu.png
# Issue with image /content/dataset/nebulas/1S4mwI79N2yz_130x130_CM1Bwh4w.png
# Issue with image /content/dataset/nebulas/TRE64TYvoKge_130x130_bWYGIkSK.png
# Issue with image /content/dataset/nebulas/PIA13108thumb.jpg
# Issue with image /content/dataset/nebulas/UcNMsh0GMd0f_130x130_P2BOU5gd.png
# Issue with image /content/dataset/nebulas/Z-k5GbgDn3JJ_130x130_hdLkpuR2.png
# Issue with image /content/dataset/nebulas/PIA24579thumb.jpg
# Issue with image /content/dataset/nebulas/F-JvKK8X8l7o_130x130_1O5DNXkM.png
# Issue with image /content/dataset/nebulas/lxr6Z-RSfG9e_130x130_ong1WYYn.png
# Issue with image /content/dataset/nebulas/H5UenpZXj2lw_130x130_jU27a-Zk.png
# Issue with image /content/dataset/nebulas/dOVvXmSgDAzN_130x130_23U-EeBy.png
# Issue with image /content/dataset/nebulas/I7RTsUfDyZQ5_130x130_Rk4gEB8G.png
# Issue with image /content/dataset/nebulas/7BqGlgJspild_130x130_3-V3nCpr.png
# Issue with image /content/dataset/nebulas/PIA09266thumb.jpg
# Issue with image /content/dataset/nebulas/PIA14415thumb.jpg
# Issue with image /content/dataset/nebulas/X-8UD1kfqnzq_130x130_I79qL6mp.png
# Issue with image /content/dataset/nebulas/MiBqF7V7QGsK_130x130_Xv6abbZu.png
# Issue with image /content/dataset/nebulas/PIA09962thumb.jpg
# Issue with image /content/dataset/nebulas/PIA04215thumb.jpg
# Issue with image /content/dataset/nebulas/PIA17834thumb.jpg
# Issue with image /content/dataset/nebulas/S17lCJ3C-wrL_130x130_P9iDxNti.png
# Issue with image /content/dataset/nebulas/JcZ9gLOSmqb2_130x130_KTTqN1G6.png
# Issue with image /content/dataset/nebulas/PIA18164thumb.jpg
# Issue with image /content/dataset/nebulas/OMexP53CMwVW_130x130_CeCHG1SC.png
# Issue with image /content/dataset/nebulas/PIA09267thumb.jpg
# Issue with image /content/dataset/nebulas/TMidwd2t9Blk_130x130_OCr-rVVB.png
# Issue with image /content/dataset/nebulas/PIA09108thumb.jpg
# Issue with image /content/dataset/nebulas/PIA15817thumb.jpg
# Issue with image /content/dataset/nebulas/PIA15413thumb.jpg
# Issue with image /content/dataset/nebulas/IsVBZNnxUnxC_130x130_K478BGcP.png
# Issue with image /content/dataset/nebulas/PIA14442thumb.jpg
# Issue with image /content/dataset/nebulas/fVJbWHfjJrAf_130x130_5rgYhund.png
# Issue with image /content/dataset/nebulas/hKO8psOtcaS3_130x130_QunJrU4m.png
# Issue with image /content/dataset/nebulas/XBX8-4a8f7dr_130x130_GXEhsYcm.png
# Issue with image /content/dataset/nebulas/PIA05062thumb.jpg
# Issue with image /content/dataset/galaxies/nnILKDiDq1qM_130x130_IcxvgUmr.png
# Issue with image /content/dataset/galaxies/image6.jpeg
# Issue with image /content/dataset/galaxies/KkvX1bH-HnZ6_130x130_HfoJTWKG.png
# Issue with image /content/dataset/galaxies/eiaLWKgZZq4H_130x130_l2LgKXsb.png
# Issue with image /content/dataset/galaxies/AtLp24baK9ak_130x130_jYhMNef-.png
# Issue with image /content/dataset/galaxies/images7.jpg
# Issue with image /content/dataset/galaxies/vy3lWkNnjQsk_130x130_VuzfVg0D.png
# Issue with image /content/dataset/galaxies/2dfriklg_sparkling-galaxy-240_625x300_23_June_22.jpg
# Issue with image /content/dataset/galaxies/OJ1CS7eHfNoD_130x130_gRil3qw7.png
# Issue with image /content/dataset/galaxies/images10.jpg
# Issue with image /content/dataset/galaxies/VpjmAA107CbB_130x130_2kBM7q86.png
# Issue with image /content/dataset/galaxies/galaxy(12).jpeg
# Issue with image /content/dataset/galaxies/5rvtxsDuS0wv_130x130_t2NJoYuq.png
# Issue with image /content/dataset/galaxies/image21.jpeg
# Issue with image /content/dataset/galaxies/galaxy(1).jpeg
# Issue with image /content/dataset/galaxies/image10.jpeg
# Issue with image /content/dataset/galaxies/images29.jpg
# Issue with image /content/dataset/galaxies/0d284abed13b97476813a9e8eb4a4f1e31fc3699.gif
# Issue with image /content/dataset/galaxies/ziONclDYywk6_130x130_Y-GEcRGH.png
# Issue with image /content/dataset/galaxies/galaxy(31).jpeg
# Issue with image /content/dataset/galaxies/AieEii6f1A0a_130x130_1jeR76JS.png
# Issue with image /content/dataset/galaxies/images5.jpg
# Issue with image /content/dataset/galaxies/Ru_SQO0zy0hv_130x130_KbNTe7al.png
# Issue with image /content/dataset/galaxies/1uwEdrM-zfFH_130x130_veq9mmBL.png
# Issue with image /content/dataset/galaxies/fbzbgfr_7l6s_130x130_4684C7GS.png
# Issue with image /content/dataset/galaxies/JPXM8O_HzY6e_130x130_ZK_HfeB1.png
# Issue with image /content/dataset/galaxies/LK405Z47ju2C_130x130_cz77jAHc.png
# Issue with image /content/dataset/galaxies/galaxy-nasa-huble-credit-nasa.jpg
# Issue with image /content/dataset/galaxies/images13.jpg
# Issue with image /content/dataset/galaxies/image28.jpeg
# Issue with image /content/dataset/galaxies/icFynuS8SQSr_130x130_2diT6zDB.png
# Issue with image /content/dataset/galaxies/tUJyPbK3b1OM_130x130_8gpc1_yv.png
# Issue with image /content/dataset/galaxies/DqubIoi1viIf_130x130_2vIu2wRP.png
# Issue with image /content/dataset/galaxies/laQmTRQqs7_J_130x130_z5QhNN7y.png
# Issue with image /content/dataset/galaxies/6GBXT9KeWmfz_130x130_dDnzUbuX.png
# Issue with image /content/dataset/galaxies/B2Ml9dRXO2iV_130x130_REgKqLIG.png
# Issue with image /content/dataset/galaxies/7aVpgTzw37Zl_130x130_WKR3REgG.png
# Issue with image /content/dataset/galaxies/andromeda_1679467871282_1679467883350_1679467883350.jpg
# Issue with image /content/dataset/galaxies/8hYg9kgJGtlO_130x130_dt93rLx0.png
# Issue with image /content/dataset/galaxies/HFFF4dwfjY9B_130x130_Jk6VFPut.png
# Issue with image /content/dataset/galaxies/rzR96mJuMYgw_130x130_P2BOU5gd.png
# Issue with image /content/dataset/galaxies/image24.jpeg
# Issue with image /content/dataset/galaxies/images34.jpg
# Issue with image /content/dataset/galaxies/galaxy(18).jpeg
# Issue with image /content/dataset/galaxies/RS3V0yW_67eR_130x130_TRGRY7y5.png
# Issue with image /content/dataset/galaxies/tPWHVd2yAX4k_130x130_HeGFm0yI.png
# Issue with image /content/dataset/galaxies/h12M4l-6ubFZ_130x130_JCXPD7ow.png
# Issue with image /content/dataset/galaxies/vm4o4rlg_disturbed-spiral-galaxy-270_625x300_26_May_22.jpg
# Issue with image /content/dataset/galaxies/NTIgkL6noYy4_130x130_VVFQbZyG.png
# Issue with image /content/dataset/galaxies/tjhnCYN-xbl__130x130_823CSUXg.png
# Issue with image /content/dataset/galaxies/galaxy(10).jpeg
# Issue with image /content/dataset/galaxies/pnHWpXddmR4O_130x130_tEzJGtts.png
# Issue with image /content/dataset/galaxies/3neN7XHa8Kz2_130x130_aH5C4FJx.png
# Issue with image /content/dataset/galaxies/galaxy(30).jpeg
# Issue with image /content/dataset/galaxies/8DITqMLh1qY2_130x130_oQbnMlox.png
# Issue with image /content/dataset/galaxies/galaxy.jpeg
# Issue with image /content/dataset/galaxies/hubble_friday_01152016.jpg
# Issue with image /content/dataset/galaxies/Untitled_design_1655786632469_1655786645118.jpg
# Issue with image /content/dataset/galaxies/eckbHsp5iKdF_130x130_VvIar86E.png
# Issue with image /content/dataset/galaxies/5wh_EOZERlWg_130x130_-4pxNYC5.png
# Issue with image /content/dataset/galaxies/Ks1M92U95V8Y_130x130_LeXJavyU.png
# Issue with image /content/dataset/galaxies/R8lCET7Xrn6m_130x130_Ep18Mp3x.png
# Issue with image /content/dataset/galaxies/uMgaYF7dLE4C_130x130_1VH-2EJ6.png
# Issue with image /content/dataset/galaxies/WM_5V4mxq5SU_130x130_3AUzkfsl.png
# Issue with image /content/dataset/galaxies/Fxi-Eik89U4G_130x130_30z7wxss.png
# Issue with image /content/dataset/galaxies/er_7WidB-NWS_130x130_Sc-upKXp.png
# Issue with image /content/dataset/galaxies/galaxy(27).jpeg
# Issue with image /content/dataset/galaxies/ALeNWUWuuLQO_130x130_pRacC9ia.png
# Issue with image /content/dataset/galaxies/X6lJ9CxmOEug_130x130_y6SFbLxQ.png
# Issue with image /content/dataset/galaxies/310px-NGC_4414_28NASA-med29.jpg
# Issue with image /content/dataset/galaxies/Q-YZ6OcqzfGo_130x130_M0D8IE43.png
# Issue with image /content/dataset/galaxies/image13.jpeg
# Issue with image /content/dataset/galaxies/images8.jpg
# Issue with image /content/dataset/galaxies/9CnUg34BcC88_130x130_VeJCWt_M.PNG.jpg
# Issue with image /content/dataset/galaxies/es-universe-awesome-deep-space-billions-galaxies-universe-elements-132153479.jpg
# Issue with image /content/dataset/galaxies/YDLbKmYEQ8X8_130x130_W2vOlT82.png
# Issue with image /content/dataset/galaxies/images19.jpg
# Issue with image /content/dataset/galaxies/Fr0xx-mxhbOT_130x130_xPj8mqyn.png
# Issue with image /content/dataset/galaxies/enUGNkBhmto3_130x130_NTtAB61U.png
# Issue with image /content/dataset/galaxies/BPuJ5MIz-hPl_130x130_szhqqI_D.png
# Issue with image /content/dataset/galaxies/J4dQ6AgGWk6A_130x130_OTAIItFC.png
# Issue with image /content/dataset/galaxies/yCeHCfaUvAIB_130x130_tUt77qI3.png
# Issue with image /content/dataset/galaxies/maxresdefault.jpg
# Issue with image /content/dataset/galaxies/galaxy(9).jpeg
# Issue with image /content/dataset/galaxies/dE4AAReEyISH_130x130_1pJtj96-.png
# Issue with image /content/dataset/galaxies/DqMFEt213HYN_130x130_4N_p4aXs.png
# Issue with image /content/dataset/galaxies/rq4uzeuFMzDg_130x130_u5RaOySi.png
# Issue with image /content/dataset/galaxies/ukh1BzFg3si7_130x130_Sz086tw_.png
# Issue with image /content/dataset/galaxies/q5dLUR1HBMK3_130x130_T3fa3ucY.png
# Issue with image /content/dataset/galaxies/2LMqUrcf7ByL_130x130_McozuDbh.png
# ...
# Issue with image /content/dataset/meteors-asteroids/images153.jpg
# Issue with image /content/dataset/meteors-asteroids/UCtUGVYgPXP9UCL9AnkE4F.jpg
# Issue with image /content/dataset/meteors-asteroids/images122.jpg
# Issue with image /content/dataset/meteors-asteroids/Screen-Shot-2023-03-08-at-10.10.48-AM.png
# Issue with image /content/dataset/meteors-asteroids/Asteroid-alert-NASA-tracks-asteroid-close-approach-hit-Earth-asteroid-news-1253324.jpg
# Issue with image /content/dataset/meteors-asteroids/images144.jpg
# Issue with image /content/dataset/meteors-asteroids/images47.jpg
# Issue with image /content/dataset/meteors-asteroids/images34.jpg
# Issue with image /content/dataset/meteors-asteroids/images127.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid-for-web_7p78.1248.jpg
# Issue with image /content/dataset/meteors-asteroids/images16.jpg
# Issue with image /content/dataset/meteors-asteroids/image.jpeg
# Issue with image /content/dataset/meteors-asteroids/images141.jpg
# Issue with image /content/dataset/meteors-asteroids/images170.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid_1675917264324_1679460093892_1679460093892.jpg
# Issue with image /content/dataset/meteors-asteroids/comet-borrelly-pia03504-16x9-1.jpg
# Issue with image /content/dataset/meteors-asteroids/images45.jpg
# Issue with image /content/dataset/meteors-asteroids/image13.jpeg
# Issue with image /content/dataset/meteors-asteroids/images8.jpg
# Issue with image /content/dataset/meteors-asteroids/images162.jpg
# Issue with image /content/dataset/meteors-asteroids/images77.jpg
# Issue with image /content/dataset/meteors-asteroids/nasa-monitors-asteroid-likely-to-hit-earth-on-valentines-day-in-2046.jpg
# Issue with image /content/dataset/meteors-asteroids/images128.jpg
# Issue with image /content/dataset/meteors-asteroids/comet-hartley-pia13570-16x9-1.jpg
# Issue with image /content/dataset/meteors-asteroids/1687900160910_416x234_thumbnail.jpg
# Issue with image /content/dataset/meteors-asteroids/photo2.jpg
# Issue with image /content/dataset/meteors-asteroids/images66.jpg
# Issue with image /content/dataset/meteors-asteroids/images126.jpg
# Issue with image /content/dataset/meteors-asteroids/images168.jpg
# Issue with image /content/dataset/meteors-asteroids/shutterstock_1925233691.jpg
# Issue with image /content/dataset/meteors-asteroids/images18.jpg
# Issue with image /content/dataset/meteors-asteroids/230309103814-asteroid-collision-risk-2046-nasa-screenshot.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroids-passing-earth.jpg
# Issue with image /content/dataset/meteors-asteroids/images23.jpg
# Issue with image /content/dataset/meteors-asteroids/2022-09-26T093323Z_693210693_RC2COW918XQH_RTRMADP_3_SPACE-EXPLORATION-ASTEROID-1024x576.jpg
# Issue with image /content/dataset/meteors-asteroids/images107.jpg
# Issue with image /content/dataset/meteors-asteroids/images108.jpg
# Issue with image /content/dataset/meteors-asteroids/images101.jpg
# Issue with image /content/dataset/meteors-asteroids/Asteroid-Earth_1672116114423_1680754184048_1680754184048.jpg
# Issue with image /content/dataset/meteors-asteroids/images78.jpg
# Issue with image /content/dataset/meteors-asteroids/images146.jpg
# Issue with image /content/dataset/meteors-asteroids/images.jpg
# Issue with image /content/dataset/meteors-asteroids/images21.jpg
# Issue with image /content/dataset/meteors-asteroids/SPACE-ASTRONOMY-ASTEROID-0_1683132681194_1689477299600.jpg
# Issue with image /content/dataset/meteors-asteroids/images103.jpg
# Issue with image /content/dataset/meteors-asteroids/images85.jpg
# Issue with image /content/dataset/meteors-asteroids/images30.jpg
# Issue with image /content/dataset/meteors-asteroids/images106.jpg
# Issue with image /content/dataset/meteors-asteroids/d41586-020-02910-4_18482686.jpg
# Issue with image /content/dataset/meteors-asteroids/images91.jpg
# Issue with image /content/dataset/meteors-asteroids/images138.jpg
# Issue with image /content/dataset/meteors-asteroids/images137.jpg
# Issue with image /content/dataset/meteors-asteroids/images20.jpg
# Issue with image /content/dataset/meteors-asteroids/bam-nasa-spacecraft-cr-1.jpg
# Issue with image /content/dataset/meteors-asteroids/images157.jpg
# Issue with image /content/dataset/meteors-asteroids/images145.jpg
# Issue with image /content/dataset/meteors-asteroids/images52.jpg
# Issue with image /content/dataset/meteors-asteroids/images63.jpg
# Issue with image /content/dataset/meteors-asteroids/image16.jpeg
# Issue with image /content/dataset/meteors-asteroids/PIA02494orig.jpg
# Issue with image /content/dataset/meteors-asteroids/images135.jpg
# Issue with image /content/dataset/meteors-asteroids/images46.jpg
# Issue with image /content/dataset/meteors-asteroids/image9.jpeg
# Issue with image /content/dataset/meteors-asteroids/NASA-asteroid-warning-Asteroid-KW4-one-mile-Earth-approach-1131960.jpg
# Issue with image /content/dataset/meteors-asteroids/image4.jpeg
# Issue with image /content/dataset/meteors-asteroids/images51.jpg
# Issue with image /content/dataset/meteors-asteroids/image18.jpeg
# Issue with image /content/dataset/meteors-asteroids/images68.jpg
# Issue with image /content/dataset/meteors-asteroids/images50.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid-4063790_960_720_1670757436603_1679372207774_1679372207774.jpg
# Issue with image /content/dataset/meteors-asteroids/image2.jpeg
# Issue with image /content/dataset/meteors-asteroids/hero-image.fill.size_1248x702.v1681503374.jpg
# Issue with image /content/dataset/meteors-asteroids/hi-852-asteroid-nasa.jpg
# Issue with image /content/dataset/meteors-asteroids/PIA02494orig2.jpg
# Issue with image /content/dataset/meteors-asteroids/230906122933-06-nasa-osiris-rex-sample-training-bennu.jpg
# Issue with image /content/dataset/meteors-asteroids/bennu-beauty.jpg
# Issue with image /content/dataset/meteors-asteroids/images72.jpg
# Issue with image /content/dataset/meteors-asteroids/image12.jpeg
# Issue with image /content/dataset/meteors-asteroids/180621-asteroid-al-0944.jpg
# Issue with image /content/dataset/meteors-asteroids/images110.jpg
# Issue with image /content/dataset/meteors-asteroids/photo.jpg
# Issue with image /content/dataset/meteors-asteroids/images3.jpg
# Issue with image /content/dataset/meteors-asteroids/images86.jpg
# Issue with image /content/dataset/meteors-asteroids/comet-hartley-pia13570-16x9-12.jpg
# Issue with image /content/dataset/meteors-asteroids/images89.jpg
# Issue with image /content/dataset/meteors-asteroids/bennu-beauty-800x450.jpg
# Issue with image /content/dataset/meteors-asteroids/Hero_342.jpg
# Issue with image /content/dataset/meteors-asteroids/GSFC_20171208_Archive_e000946orig2.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid-bennu-.jpg
# Issue with image /content/dataset/meteors-asteroids/image15.jpeg
# Issue with image /content/dataset/meteors-asteroids/MIT-Psyche-Maps-01-press.jpg
# Issue with image /content/dataset/meteors-asteroids/images32.jpg
# Issue with image /content/dataset/meteors-asteroids/images142.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid-strike.jpg
# Issue with image /content/dataset/meteors-asteroids/redirected_asteroid_will_pass_earth_this_weekend.00_00_38_25.still011.png
# Issue with image /content/dataset/meteors-asteroids/images94.jpg
# Issue with image /content/dataset/meteors-asteroids/images116.jpg
# Issue with image /content/dataset/meteors-asteroids/image8.jpeg
# Issue with image /content/dataset/meteors-asteroids/images131.jpg
# Issue with image /content/dataset/meteors-asteroids/images17.jpg
# Issue with image /content/dataset/meteors-asteroids/images114.jpg
# Issue with image /content/dataset/meteors-asteroids/image5.jpeg
# Issue with image /content/dataset/meteors-asteroids/images49.jpg
# Issue with image /content/dataset/meteors-asteroids/images43.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid_psyche_nasa_jpl_calech_asu_1655728987571.jpg
# Issue with image /content/dataset/meteors-asteroids/images129.jpg
# Issue with image /content/dataset/meteors-asteroids/skynews-asteroid-bennu-image_4697184.jpg
# Issue with image /content/dataset/meteors-asteroids/comet-borrelly-pia03504-16x9-12.jpg
# Issue with image /content/dataset/meteors-asteroids/images151.jpg
# Issue with image /content/dataset/meteors-asteroids/images96.jpg
# Issue with image /content/dataset/meteors-asteroids/479602main_eros_946-710.jpg
# Issue with image /content/dataset/meteors-asteroids/image23.jpeg
# Issue with image /content/dataset/meteors-asteroids/images67.jpg
# Issue with image /content/dataset/meteors-asteroids/images136.jpg
# Issue with image /content/dataset/meteors-asteroids/images83.jpg
# Issue with image /content/dataset/meteors-asteroids/images26.jpg
# Issue with image /content/dataset/meteors-asteroids/images69.jpg
# Issue with image /content/dataset/meteors-asteroids/images12.jpg
# Issue with image /content/dataset/meteors-asteroids/image19.jpeg
# Issue with image /content/dataset/meteors-asteroids/images31.jpg
# Issue with image /content/dataset/meteors-asteroids/images150.jpg
# Issue with image /content/dataset/meteors-asteroids/images81.jpg
# Issue with image /content/dataset/meteors-asteroids/images123.jpg
# Issue with image /content/dataset/meteors-asteroids/images57.jpg
# Issue with image /content/dataset/meteors-asteroids/images62.jpg
# Issue with image /content/dataset/meteors-asteroids/all_dimorphos_dart_0401930040_12262_01_raw_0.png
# Issue with image /content/dataset/meteors-asteroids/13.8-Death-From-the-Skies_Lead.jpg
# Issue with image /content/dataset/meteors-asteroids/image20.jpeg
# Issue with image /content/dataset/meteors-asteroids/PIA24471orig.jpg
# Issue with image /content/dataset/meteors-asteroids/GSFC_20171208_Archive_e000946orig.jpg
# Issue with image /content/dataset/meteors-asteroids/images65.jpg
# Issue with image /content/dataset/meteors-asteroids/images164.jpg
# Issue with image /content/dataset/meteors-asteroids/dart-zoom_bkg-nologos1_custom-268e95e828cae857c4ede745a46aa330197d8961-s1100-c50.jpg
# Issue with image /content/dataset/meteors-asteroids/images102.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid20161103-16_3.jpg
# Issue with image /content/dataset/meteors-asteroids/Hubble-ksrH--621x414LiveMint.jpg
# Issue with image /content/dataset/meteors-asteroids/Asteroid_4.jpg
# Issue with image /content/dataset/meteors-asteroids/image14.jpeg
# Issue with image /content/dataset/meteors-asteroids/images93.jpg
# Issue with image /content/dataset/meteors-asteroids/images100.jpg
# Issue with image /content/dataset/meteors-asteroids/images27.jpg
# Issue with image /content/dataset/meteors-asteroids/asteroid-nasa-stock-getty.jpg
# Issue with image /content/dataset/meteors-asteroids/Asteroides20cercanos20a20la20Tierra.jpg
# Issue with image /content/dataset/meteors-asteroids/images84.jpg
# Issue with image /content/dataset/meteors-asteroids/images166.jpg
# Issue with image /content/dataset/meteors-asteroids/images158.jpg
# Issue with image /content/dataset/meteors-asteroids/Asteroid-news-NASA-breaks-silence-killer-asteroid-approach-Earth-NEO-asteroid-PZ39-1242403.jpg
# Issue with image /content/dataset/meteors-asteroids/images36.jpg
# Issue with image /content/dataset/meteors-asteroids/jpegPIA23554.2e16d0ba.fill-1024x441-c10.jpg
# Issue with image /content/dataset/meteors-asteroids/images140.jpg
# Issue with image /content/dataset/meteors-asteroids/images2.jpg
# Issue with image /content/dataset/meteors-asteroids/images76.jpg
# Issue with image /content/dataset/meteors-asteroids/images99.jpg
# Issue with image /content/dataset/meteors-asteroids/images64.jpg
# Issue with image /content/dataset/meteors-asteroids/images74.jpg
# Issue with image /content/dataset/meteors-asteroids/images92.jpg
# Issue with image /content/dataset/meteors-asteroids/images53.jpg
# Issue with image /content/dataset/meteors-asteroids/images125.jpg
# Issue with image /content/dataset/meteors-asteroids/images54.jpg
# Issue with image /content/dataset/meteors-asteroids/27asteroid-vidcover-jumbo.jpg
# Issue with image /content/dataset/meteors-asteroids/images156.jpg
# Issue with image /content/dataset/meteors-asteroids/images15.jpg
# Issue with image /content/dataset/meteors-asteroids/massive-asteroids-rush-towards-earth-nasa-releases-list.jpg
# Issue with image /content/dataset/meteors-asteroids/images88.jpg
# Issue with image /content/dataset/meteors-asteroids/images73.jpg
# Issue with image /content/dataset/meteors-asteroids/images121.jpg
# Issue with image /content/dataset/meteors-asteroids/Vesta_in_natural_color_1672893086072_1673930296320_1673930296320.jpg
# Issue with image /content/dataset/meteors-asteroids/images41.jpg
# Issue with image /content/dataset/meteors-asteroids/images35.jpg
# Issue with image /content/dataset/meteors-asteroids/images71.jpg
# Issue with image /content/dataset/meteors-asteroids/images22.jpg
# Issue with image /content/dataset/meteors-asteroids/images139.jpg
# Issue with image /content/dataset/meteors-asteroids/images42.jpg
# Issue with image /content/dataset/meteors-asteroids/image22.jpeg
# Issue with image /content/dataset/meteors-asteroids/2021_03_22_111551_1616400460._large.jpg
# Issue with image /content/dataset/meteors-asteroids/images14.jpg
# Issue with image /content/dataset/meteors-asteroids/image3.jpeg
# Issue with image /content/dataset/meteors-asteroids/image7.jpeg
# Issue with image /content/dataset/meteors-asteroids/images118.jpg
# Issue with image /content/dataset/meteors-asteroids/images169.jpg
# Issue with image /content/dataset/meteors-asteroids/images95.jpg
# Issue with image /content/dataset/meteors-asteroids/image11.jpeg
# Issue with image /content/dataset/meteors-asteroids/image17.jpeg
# Issue with image /content/dataset/meteors-asteroids/images163.jpg
# Issue with image /content/dataset/meteors-asteroids/images112.jpg
# Issue with image /content/dataset/meteors-asteroids/NASA-asteroid-tracker-asteroid-2019-GN-Earth-close-approach-Moon-1113409.jpg
# Issue with image /content/dataset/meteors-asteroids/images48.jpg
# Issue with image /content/dataset/meteors-asteroids/images152.jpg
# Issue with image /content/dataset/test/meteors-asteroids(2).jpg
# Issue with image /content/dataset/test/blackhole.jpg
# Issue with image /content/dataset/test/galaxies.png
# Issue with image /content/dataset/test/blackhole(1).jpg
# Issue with image /content/dataset/test/meteors-asteroids(4).jpg
# Issue with image /content/dataset/test/blackhole(2).jpg
# Issue with image /content/dataset/test/stars(3).png
# Issue with image /content/dataset/test/meteors-asteroids(1).jpg
# Issue with image /content/dataset/test/nebulas(2).png
# Issue with image /content/dataset/test/blackhole(4).jpg
# Issue with image /content/dataset/test/nebulas(1).png
# Issue with image /content/dataset/test/galaxies(4).png
# Issue with image /content/dataset/test/stars(2).png
# Issue with image /content/dataset/test/blackhole(3).jpg
# Issue with image /content/dataset/test/planets(1).png
# Issue with image /content/dataset/test/meteors-asteroids.jpg
# Issue with image /content/dataset/test/planets.png
# Issue with image /content/dataset/test/nebulas(3).png
# Issue with image /content/dataset/test/stars(1).png
# Issue with image /content/dataset/test/planets(2).png
# Issue with image /content/dataset/test/meteors-asteroids(3).jpg
# Issue with image /content/dataset/test/stars.png
# Issue with image /content/dataset/test/planets(3).png
# Issue with image /content/dataset/test/galaxies(1).png
# Issue with image /content/dataset/test/stars(4).png
# Issue with image /content/dataset/test/galaxies(2).png
# Issue with image /content/dataset/test/nebulas.png
# Issue with image /content/dataset/test/galaxies(3).png
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-18-cb470e62abea> in <cell line: 1>()
#       1 for image_class in os.listdir(data_dir):
# ----> 2     for image in os.listdir(os.path.join(data_dir, image_class)):
#       3         image_path = os.path.join(data_dir, image_class, image)
#       4         try :
#       5             img = cv2.imread(image_path)
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/dataset/test.csv'

# %%
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)

validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)

# %%
train_galaxies_dir = os.path.join(train_dir, 'galaxies')
os.mkdir(train_galaxies_dir)

train_black_holes_dir = os.path.join(train_dir, 'blackholes')
os.mkdir(train_black_holes_dir)

train_stars_dir = os.path.join(train_dir, 'stars')
os.mkdir(train_stars_dir)

train_nebulas_dir = os.path.join(train_dir, 'nebulas')
os.mkdir(train_nebulas_dir)

train_planets_dir = os.path.join(train_dir, 'planets')
os.mkdir(train_planets_dir)

train_asteroids_meteors_dir = os.path.join(train_dir, 'meteors-asteroids')
os.mkdir(train_asteroids_meteors_dir)

# %%
validation_galaxies_dir = os.path.join(validation_dir, 'galaxies')
os.mkdir(validation_galaxies_dir)

validation_black_holes_dir = os.path.join(validation_dir, 'blackholes')
os.mkdir(validation_black_holes_dir)

validation_stars_dir = os.path.join(validation_dir, 'stars')
os.mkdir(validation_stars_dir)

validation_nebulas_dir = os.path.join(validation_dir, 'nebulas')
os.mkdir(validation_nebulas_dir)

validation_planets_dir = os.path.join(validation_dir, 'planets')
os.mkdir(validation_planets_dir)

validation_asteroids_meteors_dir = os.path.join(validation_dir, 'meteors-asteroids')
os.mkdir(validation_asteroids_meteors_dir)

# %%
def split_data(SOURCE, TRAINING, VALIDATION, SPLIT_SIZE):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else :
            print(filename + "is zero length, so ignoring.")

    training_length = int(len(files) * SPLIT_SIZE)
    valid_length = int(len(files) - training_length)
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    valid_set = shuffled_set[training_length:]

    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        copyfile(this_file, destination)

    for filename in valid_set:
        this_file = SOURCE + filename
        destination = VALIDATION + filename
        copyfile(this_file, destination)

# %%
STARS_SOURCE_DIR = '/content/dataset/stars/'
TRAINING_STARS_DIR = '/content/celestial-bodies-data/train/stars/'
VALID_STARS_DIR = '/content/celestial-bodies-data/validation/stars/'

PLANETS_SOURCE_DIR = '/content/dataset/planets/'
TRAINING_PLANETS_DIR = '/content/celestial-bodies-data/train/planets/'
VALID_PLANETS_DIR = '/content/celestial-bodies-data/validation/planets/'

NEBULAS_SOURCE_DIR = '/content/dataset/nebulas/'
TRAINING_NEBULAS_DIR = '/content/celestial-bodies-data/train/nebulas/'
VALID_NEBULAS_DIR = '/content/celestial-bodies-data/validation/nebulas/'

GALAXIES_SOURCE_DIR = '/content/dataset/galaxies/'
TRAINING_GALAXIES_DIR = '/content/celestial-bodies-data/train/galaxies/'
VALID_GALAXIES_DIR = '/content/celestial-bodies-data/validation/galaxies/'

BLACKHOLES_SOURCE_DIR = '/content/dataset/blackholes/'
TRAINING_BLACKHOLES_DIR = '/content/celestial-bodies-data/train/blackholes/'
VALID_BLACKHOLES_DIR = '/content/celestial-bodies-data/validation/blackholes/'

ASTEROIDS_METEORS_SOURCE_DIR = '/content/dataset/meteors-asteroids/'
TRAINING_ASTEROIDS_METEORS_DIR = '/content/celestial-bodies-data/train/meteors-asteroids/'
VALID_ASTEROIDS_METEORS_DIR = '/content/celestial-bodies-data/validation/meteors-asteroids/'

# %%
import random
from shutil import copyfile

# %%
split_size = .85

# %%
split_data(STARS_SOURCE_DIR, TRAINING_STARS_DIR, VALID_STARS_DIR, split_size)
split_data(PLANETS_SOURCE_DIR, TRAINING_PLANETS_DIR, VALID_PLANETS_DIR, split_size)
split_data(NEBULAS_SOURCE_DIR, TRAINING_NEBULAS_DIR, VALID_NEBULAS_DIR, split_size)
split_data(GALAXIES_SOURCE_DIR, TRAINING_GALAXIES_DIR, VALID_GALAXIES_DIR, split_size)
split_data(BLACKHOLES_SOURCE_DIR, TRAINING_BLACKHOLES_DIR, VALID_BLACKHOLES_DIR, split_size)
split_data(ASTEROIDS_METEORS_SOURCE_DIR, TRAINING_ASTEROIDS_METEORS_DIR, VALID_ASTEROIDS_METEORS_DIR, split_size)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread
import pathlib

# %%
image_folder = ['stars', 'planets', 'nebulas', 'meteors-asteroids', 'galaxies', 'blackholes']
nimgs = {}
for i in image_folder:
    nimages = len(os.listdir('/content/celestial-bodies-data/train/'+i+'/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Training Dataset')
plt.show()

# %%
for i in ['stars', 'planets', 'nebulas', 'meteors-asteroids', 'galaxies', 'blackholes']:
    print('Training {} images are: '.format(i)+str(len(os.listdir('/content/celestial-bodies-data/train/'+i+'/'))))
# Out:
# Training stars images are: 272
# Training planets images are: 195
# Training nebulas images are: 174
# Training meteors-asteroids images are: 170
# Training galaxies images are: 251
# Training blackholes images are: 137

# %%
image_folder = ['stars', 'planets', 'nebulas', 'meteors-asteroids', 'galaxies', 'blackholes']
nimgs = {}
for i in image_folder:
    nimages = len(os.listdir('/content/celestial-bodies-data//validation/'+i+'/'))
    nimgs[i]=nimages
plt.figure(figsize=(9, 6))
plt.bar(range(len(nimgs)), list(nimgs.values()), align='center')
plt.xticks(range(len(nimgs)), list(nimgs.keys()))
plt.title('Distribution of different classes in Validation Dataset')
plt.show()

# %%
for i in ['stars', 'planets', 'nebulas', 'meteors-asteroids', 'galaxies', 'blackholes']:
    print('Validation {} images are: '.format(i)+str(len(os.listdir('/content/celestial-bodies-data/validation/'+i+'/'))))
# Out:
# Validation stars images are: 48
# Validation planets images are: 35
# Validation nebulas images are: 31
# Validation meteors-asteroids images are: 31
# Validation galaxies images are: 45
# Validation blackholes images are: 25

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
img_width=256; img_height=256
batch_size=16

# %%
TRAINING_DIR = '/content/celestial-bodies-data/train/'

train_datagen = ImageDataGenerator(rescale = 1/255.0,
                                   rotation_range=30,
                                   zoom_range=0.4,
                                   horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    target_size=(img_height, img_width))
# Out:
# Found 1196 images belonging to 6 classes.

# %%
VALIDATION_DIR = '/content/celestial-bodies-data/validation/'

validation_datagen = ImageDataGenerator(rescale = 1/255.0)

validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              target_size=(img_height, img_width)
                                                             )
# Out:
# Found 215 images belonging to 6 classes.

# %%
callbacks = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')
# autosave best Model
best_model_file = '/content/CNN_aug_best_weights.h5'
best_model = ModelCheckpoint(best_model_file, monitor='val_acc', verbose = 1, save_best_only = True)

# %%
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)), MaxPooling2D(2, 2),
    Conv2D(32, (3, 3), activation='relu'), MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(256, (3, 3), activation='relu'),
    Conv2D(256, (3, 3), activation='relu'),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    Dense(6, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 58, 58, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 29, 29, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 10, 10, 256)       295168
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 256)         590080
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 256)         590080
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 3203174 (12.22 MB)
# Trainable params: 3203174 (12.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics =['accuracy'])

# %%
history = model.fit_generator(train_generator,
                              epochs=30,
                              verbose=1,
                              validation_data=validation_generator,
                              callbacks = [best_model]
                              )
# Out:
# <ipython-input-40-5368c251678d>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/30
# 26/75 [=========>....................] - ETA: 1:43 - loss: 1.7866 - accuracy: 0.1990
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-40-5368c251678d> in <cell line: 1>()
# ----> 1 history = model.fit_generator(train_generator,
#       2                               epochs=30,
#       3                               verbose=1,
#       4                               validation_data=validation_generator,
#       5                               callbacks = [best_model]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2887             stacklevel=2,
#    2888         )
# -> 2889         return self.fit(
#    2890             generator,
#    2891             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# UnknownError: Graph execution error:
#
# Detected at node PyFunc defined at (most recent call last):
# <stack traces unavailable>
# OSError: image file is truncated (78 bytes not processed)
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/script_ops.py", line 270, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_generator_op.py", line 198, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py", line 917, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py", line 1064, in generator_fn
#     yield x[i]
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py", line 116, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py", line 370, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/image_utils.py", line 479, in load_img
#     img = img.resize(width_height_tuple, resample)
#
#   File "/usr/local/lib/python3.10/dist-packages/PIL/Image.py", line 2156, in resize
#     self.load()
#
#   File "/usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py", line 266, in load
#     raise OSError(msg)
#
# OSError: image file is truncated (78 bytes not processed)
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_train_function_3050]

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc = 'lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
# performance on test data
import pandas as pd
import numpy as np
from keras.preprocessing.image import load_img, img_to_array

def preprocess_image(path):
    img = load_img(path, target_size = (img_height, img_width))
    a = img_to_array(img)
    a = np.expand_dims(a, axis = 0)
    a /= 255.
    return a

# %%
# Read Test Images Dir and their labels
test_images_dir = '/content/dataset/test/'
test_df = pd.read_csv('/content/dataset/test.csv')

# put them in a list
test_dfToList = test_df['Image_id'].tolist()
test_ids = [str(item) for item in test_dfToList]

test_images = [test_images_dir+item for item in test_ids]
test_preprocessed_images = np.vstack([preprocess_image(fn) for fn in test_images])
np.save('/content/test_preproc_CNN.npy', test_preprocessed_images)

# %%
array = model.predict(test_preprocessed_images, batch_size=1, verbose=1)
answer = np.argmax(array, axis=1)
print(answer)

# %%
test_df = pd.read_csv('/content/dataset/test.csv')
y_true = test_df['labels']
y_pred = array
print(y_true)

# %%
from sklearn.metrics import log_loss
loss = log_loss(y_true, y_pred, eps=1e-15, normalize=True, sample_weight=None, labels=None)

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_true, answer)
conf_mat

# %%
train_dir = '/content/celestial-bodies-data/train/'
classes = os.listdir(train_dir)

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Reds):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = cm.round(2)
        #print("Normalized confusion matrix")
    else:
        cm=cm
        #print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
np.set_printoptions(precision=2)

fig1 = plt.figure(figsize=(7,6))
plot_confusion_matrix(conf_mat, classes=classes, title='Confusion matrix, without normalization')
plt.show()
